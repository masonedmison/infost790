# %%
# dependancies 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# wibr data
crime_master = pd.read_csv('/Users/MasonBaran/PycharmProjects/infost790/data/wibr.csv')

# %% [markdown]
# ### Observations of data
# - reports start start at 01-01-2005
# - ALD == Aldermanic District -- use this to get neighborhood

# %%
crime_master.head()
# Out:
#    IncidentNum     ReportedDateTime  ReportedYear  ReportedMonth  \
# 0    192830127  2019-10-10 19:15:00          2019             10
# 1    192830126  2019-10-10 18:00:00          2019             10
# 2    192830103  2019-10-10 15:45:00          2019             10
# 3    192830062  2019-10-10 11:30:00          2019             10
# 4    192830058  2019-10-10 11:00:00          2019             10
#
#            Location       WeaponUsed   ALD   NSP  POLICE     TRACT  ...  \
# 0     2472 N 5TH ST              NaN   6.0   6.0     5.0  185600.0  ...
# 1    2259 S 21ST PL              NaN   8.0  17.0     2.0   17400.0  ...
# 2    2947 N 12TH ST  PERSONAL WEAPON   6.0   4.0     5.0    6600.0  ...
# 3    3006 N 60TH ST              NaN  10.0   5.0     7.0    5000.0  ...
# 4  7038 W ACACIA ST              NaN   9.0   NaN     4.0     600.0  ...
#
#    Arson  AssaultOffense  Burglary  CriminalDamage  Homicide  LockedVehicle  \
# ...

# %%
crime_master.columns
# Out:
# Index(['IncidentNum', 'ReportedDateTime', 'ReportedYear', 'ReportedMonth',
#        'Location', 'WeaponUsed', 'ALD', 'NSP', 'POLICE', 'TRACT', 'WARD',
#        'ZIP', 'RoughX', 'RoughY', 'Arson', 'AssaultOffense', 'Burglary',
#        'CriminalDamage', 'Homicide', 'LockedVehicle', 'Robbery', 'SexOffense',
#        'Theft', 'VehicleTheft'],
#       dtype='object')

# %% [markdown]
# ### General Design and Thoughts
#
# - split train/ test data using Stratified Sampling --> sklearn.model_selecton.StratifiedShuffleSplit

# %%
sns.pairplot(x_vars=["RoughX"], y_vars=["RoughY"], data=crime_master, hue="ALD", height=8)

# %%
corr_matrix = crime_master.corr()

# %%
corr_matrix['ALD'].sort_values(ascending=False)
# Out:
# ALD               1.000000
# WARD              0.565085
# NSP               0.398507
# RoughX            0.137039
# TRACT             0.085997
# AssaultOffense    0.020061
# Arson             0.013650
# SexOffense        0.010766
# CriminalDamage    0.008502
# Homicide          0.004953
# Theft            -0.001560
# Robbery          -0.002628
# ReportedMonth    -0.002797
# Burglary         -0.011618
# IncidentNum      -0.012144
# ReportedYear     -0.012822
# LockedVehicle    -0.013786
# ZIP              -0.013827
# VehicleTheft     -0.014742
# POLICE           -0.095405
# RoughY           -0.511984
# Name: ALD, dtype: float64
